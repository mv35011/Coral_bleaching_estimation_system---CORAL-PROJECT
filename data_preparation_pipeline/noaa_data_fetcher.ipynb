# %%
# !python noaa_data_fetcher.py --output "coral_data_final.csv" --start-year 1990
# Out:
# ...
# --- Starting Data Acquisition for Project CORAL ---
# ...
# Fetching data for the period: 1990-01-01 to 2024-12-31
# Chunk size: 3 months per request
# Locations: 4
# Estimated total requests: 560
# Estimated time: ~46 minutes
# ...
#
# [1/4] Processing location: Andaman_Islands
#   Coordinates: (11.25, 92.77)
# ----------------------------------------------------------------------
# Fetching 1990-01-01 to 1990-03-31...
#   Attempt 1/3... Success! (90 rows)
# Fetching 1990-04-01 to 1990-06-30...
#   Attempt 1/3... Success! (91 rows)
# Fetching 1990-07-01 to 1990-09-30...
#   Attempt 1/3... Success! (92 rows)
# Fetching 1990-10-01 to 1990-12-31...
#   Attempt 1/3... Success! (92 rows)
# Fetching 1991-01-01 to 1991-03-31...
#   Attempt 1/3... Success! (90 rows)
# Fetching 1991-04-01 to 1991-06-30...
#   Attempt 1/3... Success! (91 rows)
# Fetching 1991-07-01 to 1991-09-30...
#   Attempt 1/3... Success! (92 rows)
# Fetching 1991-10-01 to 1991-12-31...
#   Attempt 1/3... Success! (92 rows)
# ...

# %%
# !python fetch_missing_data.py
# Out:
# ...
# --- Fetching Missing Data for Gulf of Mannar ---
# ...
# Fetching 1985-01-01 to 1985-03-31...
#   Attempt 1/3... Error: 404 Client Error:  for url: https://pae-paha.pacioos.hawaii.edu/erddap/griddap/dhw_5km.csv?CRW_SST%5B(1985-01-01T12:00:00Z):1:(1985-03-31T12:00:00Z)%5D%5B(8.8):1:(8.8)%5D%5B(78.25):1:(78.25)%5D%2CCRW_HOTSPOT%5B(1985-01-01T12:00:00Z):1:(1985-03-31T12:00:00Z)%5D%5B(8.8):1:(8.8)%5D%5B(78.25):1:(78.25)%5D%2CCRW_DHW%5B(1985-01-01T12:00:00Z):1:(1985-03-31T12:00:00Z)%5D%5B(8.8):1:(8.8)%5D%5B(78.25):1:(78.25)%5D%2CCRW_SSTANOMALY%5B(1985-01-01T12:00:00Z):1:(1985-03-31T12:00:00Z)%5D%5B(8.8):1:(8.8)%5D%5B(78.25):1:(78.25)%5D%2CCRW_BAA%5B(1985-01-01T12:00:00Z):1:(1985-03-31T12:00:00Z)%5D%5B(8.8):1:(8.8)%5D%5B(78.25):1:(78.25)%5D%2CCRW_BAA_7D_MAX%5B(1985-01-01T12:00:00Z):1:(1985-03-31T12:00:00Z)%5D%5B(8.8):1:(8.8)%5D%5B(78.25):1:(78.25)%5D
# ...

# %%
# In a new Colab cell, run this code:

if location_dfs:
    # Corrected line below
    location_df = pd.concat(location_dfs, ignore_index=True)
    location_df['location_name'] = "Gulf_of_Mannar" # Manually add name
    location_df = location_df.sort_values('time').reset_index(drop=True)

    output_filename = 'gulf_of_mannar_data.csv'
    location_df.to_csv(output_filename, index=False)
    print(f"\n✅ Success! Missing data saved to '{output_filename}'")
else:
    print("\n❌ FAILED: No data was found in memory.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1992402181.py in <cell line: 0>()
#       1 # In a new Colab cell, run this code:
#       2
# ----> 3 if location_dfs:
#       4     # Corrected line below
#       5     location_df = pd.concat(location_dfs, ignore_index=True)
#
# NameError: name 'location_dfs' is not defined
